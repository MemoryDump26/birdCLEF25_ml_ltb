# %% [markdown]
# # **BirdCLEF 2025 Data Preprocessing Notebook**
# This notebook demonstrates how we can transform audio data into mel-spectrogram data. This transformation is essential for training 2D Convolutional Neural Networks (CNNs) on audio data, as it converts the one-dimensional audio signals into two-dimensional image-like representations.
# I run this public notebook in debug mode(only a few sample processing). You can find the fully preprocessed mel spectrogram training dataset here --> [BirdCLEF'25 | Mel Spectrograms](https://www.kaggle.com/datasets/kadircandrisolu/birdclef25-mel-spectrograms).

# %%
import os
import cv2
import math
import time
import librosa
import pickle
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

import torch
import warnings
warnings.filterwarnings("ignore")

# %%
class Config:
 
    DEBUG_MODE = False
    
    OUTPUT_DIR = '/kaggle/working/'
    DATA_ROOT = '/kaggle/input/birdclef-2025'
    FS = 32000
    
    # Mel spectrogram parameters
    N_FFT = 1024
    HOP_LENGTH = 128
    N_MELS = 128
    FMIN = 8000
    FMAX = 16000
    
    TARGET_DURATION = 5.0
    TARGET_SHAPE = (256, 256)
    
    N_MAX = 4 if DEBUG_MODE else None

    PCEN = False
    MU_EXPAND = True

config = Config()

# %%
print(f"Debug mode: {'ON' if config.DEBUG_MODE else 'OFF'}")
print(f"Max samples to process: {config.N_MAX if config.N_MAX is not None else 'ALL'}")

print("Loading taxonomy data...")
taxonomy_df = pd.read_csv(f'{config.DATA_ROOT}/taxonomy.csv')
species_class_map = dict(zip(taxonomy_df['primary_label'], taxonomy_df['class_name']))

print("Loading training metadata...")
train_df = pd.read_csv(f'{config.DATA_ROOT}/train.csv')

print("Loading voice sammury data...")
with open("/kaggle/input/bc25-separation-voice-from-data-by-silero-vad/train_voice_summary.txt") as f:
    voice_audio_list = f.read().split("\n")

print("Loading voice data...")
with open("/kaggle/input/bc25-separation-voice-from-data-by-silero-vad/train_voice_data.pkl", "rb") as f:
    voice_data = pickle.load(f)
# Out:
# Debug mode: OFF
# Max samples to process: ALL
# Loading taxonomy data...
# Loading training metadata...
# Loading voice sammury data...
# Loading voice data...

# %%
label_list = sorted(train_df['primary_label'].unique())
label_id_list = list(range(len(label_list)))
label2id = dict(zip(label_list, label_id_list))
id2label = dict(zip(label_id_list, label_list))

print(f'Found {len(label_list)} unique species')
working_df = train_df[['primary_label', 'rating', 'filename']].copy()
working_df['target'] = working_df.primary_label.map(label2id)
working_df['filepath'] = config.DATA_ROOT + '/train_audio/' + working_df.filename
working_df['samplename'] = working_df.filename.map(lambda x: x.split('/')[0] + '-' + x.split('/')[-1].split('.')[0])
working_df['class'] = working_df.primary_label.map(lambda x: species_class_map.get(x, 'Unknown'))
total_samples = min(len(working_df), config.N_MAX or len(working_df))
print(f'Total samples to process: {total_samples} out of {len(working_df)} available')
print(f'Samples by class:')
print(working_df['class'].value_counts())
# Out:
# Found 206 unique species
# Total samples to process: 28564 out of 28564 available
# Samples by class:
# class
# Aves        27648
# Amphibia      583
# Mammalia      178
# Insecta       155
# Name: count, dtype: int64

# %%
def audio2melspec(audio_data, config):
    if np.isnan(audio_data).any():
        mean_signal = np.nanmean(audio_data)
        audio_data = np.nan_to_num(audio_data, nan=mean_signal)

    if config.MU_EXPAND:
        audio_data = np.clip(audio_data, -1, 1)
        audio_data = librosa.mu_expand(audio_data,quantize=False)
    
    mel_spec = librosa.feature.melspectrogram(
        y=audio_data,
        sr=config.FS,
        n_fft=config.N_FFT,
        hop_length=config.HOP_LENGTH,
        n_mels=config.N_MELS,
        fmin=config.FMIN,
        fmax=config.FMAX,
        power=1.0
    )

    if config.PCEN:
        pcen_S = librosa.pcen(
            mel_spec * (2**31),
            sr=config.FS,
            hop_length=128,
            time_constant=0.03,
            bias=10,
            gain=0.8,
            power=0.25
        )
        return pcen_Sp
    else:
        mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
        mel_spec_norm = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min() + 1e-8)
        return mel_spec_norm

# %%
def remove_voice(audio_data, voice_segment, config):
    # 無音区間のリストを作成
    non_voice_segments = []
    prev_end = 0

    for st in voice_segment:
        start, end = math.floor(st["start"] * config.FS), math.ceil(st["end"] * config.FS)
        if prev_end < start:
            non_voice_segments.append((prev_end, start))
        prev_end = max(prev_end, end)

    if prev_end < len(audio_data):
        non_voice_segments.append((prev_end, len(audio_data)))

    # 最も長い区間を見つける
    longest_segment = None
    max_duration = 0
    for start, end in non_voice_segments:
        segment = audio_data[start:end]
        if len(segment) > max_duration:
            max_duration = len(segment)
            longest_segment = segment
    return longest_segment

# %%
print("Starting audio processing...")
print(f"{'DEBUG MODE - Processing only 50 samples' if config.DEBUG_MODE else 'FULL MODE - Processing all samples'}")
start_time = time.time()

print(voice_audio_list[:10])

all_bird_data = {}
errors = []

for i, row in tqdm(working_df.iterrows(), total=total_samples):
    if config.N_MAX is not None and i >= config.N_MAX:
        break
    
    try:
        # 音声のロード
        audio_data, _ = librosa.load(row.filepath, sr=config.FS)

        # 人の声が入っている音声の場合...
        if row.filepath in voice_audio_list:
            # 人の声を削除したうえで一番長い部分を取得
            print(f"{row.filepath}から発話を削除")
            voice_segment = voice_data[row.filepath]
            audio_data = remove_voice(audio_data, voice_segment, config)

        target_samples = int(config.TARGET_DURATION * config.FS)

        if len(audio_data) < target_samples:
            n_copy = math.ceil(target_samples * 2 / len(audio_data))
            if n_copy > 1:
                audio_data = np.concatenate([audio_data] * n_copy)

        start_idx = max(0, int(len(audio_data) / 2 - target_samples / 2))
        end_idx = min(len(audio_data), start_idx + target_samples)
        center_audio = audio_data[start_idx:end_idx]

        if len(center_audio) < target_samples:
            center_audio = np.pad(center_audio, 
                                 (0, target_samples - len(center_audio)), 
                                 mode='constant')

        mel_spec = audio2melspec(center_audio, config)

        if mel_spec.shape != config.TARGET_SHAPE:
            mel_spec = cv2.resize(mel_spec, config.TARGET_SHAPE, interpolation=cv2.INTER_LINEAR)

        all_bird_data[row.samplename] = mel_spec.astype(np.float32)
        
    except Exception as e:
        print(f"Error processing {row.filepath}: {e}")
        errors.append((row.filepath, str(e)))

np.save(config.OUTPUT_DIR + "birdclef2025_melspec_without_voice_per5sec_256_256.npy", all_bird_data, allow_pickle=True)

oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC245381.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC493804.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC521127.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC521128.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC521129.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC521130.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC525450.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC525451.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC525452.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC525713.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC532441.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC532442.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yectyr1/XC876175.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC148203.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC148204.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC431179.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC45528.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523822.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523823.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523824.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523825.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523826.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523827.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC523828.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC57410.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC57449.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehbla2/XC820367.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148066.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148231.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148233.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148388.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148389.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148394.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148395.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148396.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148397.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148398.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148399.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148400.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148401.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148402.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC148418.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC199046.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC204714.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC204717.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC234711.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC340259.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC433372.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC433374.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC609880.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC702830.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC946064.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/XC946065.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/iNat331879.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/iNat933937.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yehcar1/iNat933938.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC312364.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC354035.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC404340.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC490898.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC558244.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC946123.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yelori1/XC959663.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC115483.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC127030.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC148256.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC148259.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC165279.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC166320.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC212999.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC214586.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC250305.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC283320.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC335915.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC386429.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC388953.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC420196.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC428099.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC433522.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC460059.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC461346.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC480011.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC512409.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC533970.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC607029.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC635420.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC677766.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC799801.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC81742.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC843599.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/XC8866.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/iNat1132425.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/iNat1290101.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/iNat222939.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/iNat407187.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/iNat629481.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yeofly1/iNat902149.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC116113.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC123791.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC127210.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC148184.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC148325.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC199036.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC244806.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC244967.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC245379.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC245380.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC245490.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC245498.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC254270.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC316726.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC443008.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC461407.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC484513.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC518223.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC525486.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC525487.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC525488.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC54579.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC54580.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC549877.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC59783.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC59784.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC59809.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC837303.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC841771.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC909094.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC9294.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/XC960285.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/yercac1/iNat922648.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC148332.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC488844.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC520746.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC520747.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC525110.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC525462.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC525463.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC525464.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC825536.oggから発話を削除
# /kaggle/input/birdclef-2025/train_audio/ywcpar/XC960831.oggから発話を削除
# Processing completed in 2305.74 seconds
# Successfully processed 28564 files out of 28564 total
# Failed to process 0 files

# %%
import matplotlib.pyplot as plt

samples = []
displayed_classes = set()

max_samples = min(4, len(all_bird_data))

for i, row in working_df.iterrows():
    if i >= (config.N_MAX or len(working_df)):
        break
        
    if row['samplename'] in all_bird_data:
        if config.DEBUG_MODE:
            if row['class'] not in displayed_classes:
                samples.append((row['samplename'], row['class'], row['primary_label']))
                #displayed_classes.add(row['class'])
        else:
            if row['class'] not in displayed_classes:
                samples.append((row['samplename'], row['class'], row['primary_label']))
                displayed_classes.add(row['class'])
        
        if len(samples) >= max_samples:  
            break

if samples:
    plt.figure(figsize=(16, 12))
    
    for i, (samplename, class_name, species) in enumerate(samples):
        plt.subplot(2, 2, i+1)
        plt.imshow(all_bird_data[samplename], aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"{class_name}: {species}")
        plt.colorbar(format='%+2.0f dB')
    
    plt.tight_layout()
    debug_note = "debug_" if config.DEBUG_MODE else ""
    plt.savefig(f'{debug_note}melspec_examples.png')
    plt.show()
